# %% [markdown]
# <a href="https://colab.research.google.com/github/andradeecla213/Programa-o-algoritimo-1F/blob/main/aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Entrada

lado1 = float(input("Digite o comprimento:"))
lado2 = float(input("Digite a altura:"))

#Processamento

area = lado1 * lado2

#Saída

print (f"O total da área é : {area} metros quadrados")
# Out:
# Digite o comprimento:3
# Digite a altura:9
# O total da área é : 27.0 metros quadrados

# %%
#Entrada

numero1 = float(input("Digite o numero"))

#Processamento

dobro = numero1 * 2

#Saída

print (f"O dobro do numero {dobro}")
# Out:
# Digite o numero9
# O dobro do numero 18.0

# %%
from re import M
#Entrada

nota1 = int (input("Digite a 1° nota"))
nota2 = int (input("Digite a 2º nota"))
nota3 = int (input("Digite a 3° nota"))
nota4 = int (input("Digite a 4° nota"))

#Processamento

media = nota1 + nota2 + nota3 + nota4
media2 = media/4

#Saída

print (f"O resultado da media das notas é {media2}")
# Out:
# Digite a 1° nota4
# Digite a 2º nota8
# Digite a 3° nota6
# Digite a 4° nota10
# O resultado da media das notas é 7.0

# %%
#Entrada
nome = str (input("Digite o seu nome completo "))
idade = int (input("Digite a sua idade! "))


#Saída

print (f"Oi {nome}, você tem {idade} anos")
# Out:
# Digite o seu nome completo Clara
# Digite a sua idade! 15
# Oi Clara, você tem 15 anos
