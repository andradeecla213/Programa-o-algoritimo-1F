# %% [markdown]
# <a href="https://colab.research.google.com/github/andradeecla213/Programa-o-algoritimo-1F/blob/main/aula02_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# projeto caixa eletronico

# você foi contratado para desesnvolver uma sistema simples de caixa eletronico
# O sistema deverá funcionar atraves de um menu interativo ultilizando "while"
#deve iniciar com um saldo inicial de 1000,00 e permitir que o usuario escolha diferentes operações até decidir sair do sistema

# ver saldo
# depositar
# sacar dinheiro
# sair

# regras:
# quando depositar somar ao saldo anterior;
# quando sacar subtrair do saldo anterior
# mostar o saldo para o usuario

# %%
print ("-----------------------MENU-----------------------")
print ("")
print ("Opção 1 - Ver saldo")
print ("Opção 2 - Depositar")
print ("Opção 3 - Sacar dinheiro")
print ("Opção 4 - sair")
print ("")
print ("==================================================")
print ("")

opcao = ""
saldo_inicial = 1000

while opcao !=0:
  try:
    opcao = int(input("olá, escolha uma das opções para iniciar ou 4 para sair: "))
    print("")

    if opcao == 1:
      print(f"Seu saldo atual é: {saldo_inicial}")

    elif opcao == 2:
      deposito = float(input("Digite o valor do deposito: "))
      saldo_inicial=deposito+saldo_inicial
      print(f"{saldo_inicial}")

    elif opcao == 3:
      deposito = float(input("Digite o valor do seu saque: "))
      saldo_inicial = saldo_inicial-deposito
      print("")

    elif opcao < 0 or opcao > 3:
      print ("Digite um número")
  except:
      print("Digite apenas números")
# Out:
# -----------------------MENU-----------------------
#
# Opção 1 - Ver saldo
# Opção 2 - Depositar
# Opção 3 - Sacar dinheiro
# Opção 4 - sair
#
# ...
#
#
# 1100.0
#
#
#
# Seu saldo atual é: 1050.0
# Digite apenas números
#
# Digite um número
#
# Digite um número
#
# Digite um número
# Digite apenas números

# %%
# Calculadora simples
# O programa recebera dois números e irá realizar uma das 4 operações matemáticas

opcao = ""
numero_a = 0
numero_b = 0

print ("----------MENU----------")
print ("")
print ("Opção 1 - Somar")
print ("Opção 2 - Subtração")
print ("Opção 3 - Multiplicação")
print ("Opção 4 - Divisão")
print ("Opção 5 - sair")
print ("======================")
print ("")

try:

  while opcao != 5:
    opcao = int(input("digite um número ou 5 para sair: "))

    if opcao == 1:

      numero_a = float (input("Digite um número: "))
      numero_b = float (input("Digite um número: "))

      print (f"O total da soma de {numero_a} + {numero_b} é igual : {numero_a + numero_b}"  )
      print ("")

    elif opcao == 2:

      numero_a = float (input("Digite um número: "))
      numero_b = float (input("Digite um número: "))

      print (f"O total da subtração do {numero_a} - {numero_b} é igual : {numero_a - numero_b}"  )
      print ("")

    elif opcao == 3:

      numero_a = float (input("Digite um número: "))
      numero_b = float (input("Digite um número: "))

      print (f"O total da multiplicação do {numero_a} * {numero_b} é igual : {numero_a * numero_b}"  )
      print ("")

    elif opcao == 4:

      numero_a = float (input("Digite um número: "))
      numero_b = float (input("Digite um número: "))

      print (f"O total da divisão do {numero_a} / {numero_b} é igual : {numero_a /numero_b}"  )
      print ("")

except:
  print ("Digite apenas número de 1 a 5")

# %%
import random

a = random.random()
print(a)

# %%
import random

a = random.randint (0,10)

print (a)

# %%
# Fazer um jogo de adivinhação
# O usúario irá adivinhar um número de 0 até 10

# regras
# O usúario terá 03 chances de acertar
# informar se opalpite do usúario é maior ou menor do que o número.
# Imprimer se está quente,morno ou frio
