# %% [markdown]
# <a href="https://colab.research.google.com/github/andradeecla213/Programa-o-algoritimo-1F/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lado1 = 4
lado2 = 3

#Cálculo da área

area = lado1 * lado2

#Cálculo da área de um quadrado

areaquadrado = lado1 * lado1

# %%
print (area)
# Out:
# 12

# %%
print (areaquadrado)
# Out:
# 16

# %%
nome = "Maria"

# %%
print(nome)
# Out:
# Maria

# %%
nome = "Clara"
idade = 15
altura = 1.67

# %%
print (f"nome : {nome}, idade : {idade}; Altura : {altura}")
# Out:
# nome : Clara, idade : 15; Altura : 1.67
